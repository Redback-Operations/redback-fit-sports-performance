# %%
from pace_curve import PaceCurveAnalyzer
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Visualise Pace curve for 90 days to Sep 2022 when Critical Speed was 3.7 m/s
pca = PaceCurveAnalyzer(data_source=None)
pace_curve = pca.create_pace_curve('Run', '2022-09-30', 90)
pca.plot_pace_curve(pace_curve, 3.7)

# %%
# Visualise Pace curve for 30 days up to Sep 2022 when Critical Speed was 3.7 m/s
pca = PaceCurveAnalyzer(data_source=None)
pace_curve = pca.create_pace_curve('Run', '2022-09-30', 30)
pca.plot_pace_curve(pace_curve, 3.7)

# %%
# Visualise Pace curve for 30 days up to Jan 2023 when Critical Speed was 3.8 m/s
pca = PaceCurveAnalyzer(data_source=None)
pace_curve = pca.create_pace_curve('Run', '2023-01-01', 30)
pca.plot_pace_curve(pace_curve, 3.8)

# %%
# Visualise Pace curve for 90 days up to Jan 2023 when Critical Speed was 0.8 m/s
pca = PaceCurveAnalyzer(data_source=None)
pace_curve = pca.create_pace_curve('Swim', '2023-01-01', 90)
pca.plot_pace_curve(pace_curve, 0.8)
